# %%
import pandas as pd

# %%
# df_15 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_15.csv', on_bad_lines='skip')
# df_16 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_16.csv', on_bad_lines='skip')
# df_17 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_17.csv', on_bad_lines='skip')
# df_18 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_18.csv', on_bad_lines='skip')
# df_19 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_19.csv', on_bad_lines='skip')
# df_20 = pd.read_csv('/content/drive/MyDrive/Dissertation Retake/players_20.csv', on_bad_lines='skip')

# %%
# df_15.head()
# df_16.head()
# df_17.head()
# df_18.head()
# df_19.head()
# df_20.head()

# df_20 = df_20.drop(['sofifa_id','player_url'],axis = 1)

# %%
# print(list(df_20.columns))

# df_20.isnull().sum() #check for columns having NaN values
# Out:
# ['short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina'
# ...

# %%
# columns = [ 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']
# df_20.loc[:,columns]
# Out:
#          ls    st    rs    lw    lf    cf    rf    rw   lam   cam  ...   lwb  \
# 0      89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  ...  68+2
# 1      91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  ...  65+3
# 2      84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  ...  66+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4      83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  ...  66+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 18273  32+2  32+2  32+2  31+2  31+2  31+2  31+2  31+2  31+2  31+2  ...  43+2
# 18274  33+2  33+2  33+2  33+2  32+2  32+2  32+2  33+2  33+2  33+2  ...  44+2
# 18275  43+2  43+2  43+2  43+2  43+2  43+2  43+2  43+2  44+2  44+2  ...  47+2
# 18276  43+2  43+2  43+2  45+2  44+2  44+2  44+2  45+2  46+2  46+2  ...  48+2
# 18277  42+2  42+2  42+2  44+2  43+2  43+2  43+2  44+2  46+2  46+2  ...  48+2
#
# ...

# %%
# Out:
# <Response [401]>

# %%
# Out:
# dict_keys(['code', 'date', 'host', 'mdc', 'path', 'status', 'techMessage', 'userMessage', 'version'])

# %%
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3511608244.py in <cell line: 0>()
#       9
#      10 for i in range(0,25):
# ---> 11     PlayersList.append(Players[i].text)
#      12     ValuesList.append(Values[i].text)
#      13     value_pre.append(Values_pre[2*i].text)
#
# IndexError: list index out of range

# %%
# import requests
# from bs4 import BeautifulSoup
# import time

# headers = {
#     "User-Agent": "Mozilla/5.0"
# }

# base_url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

# def get_players_from_page(page_number):
#     url = f"{base_url}/page/{page_number}"
#     print(f"Scraping: {url}")
#     response = requests.get(url, headers=headers)
#     soup = BeautifulSoup(response.text, "lxml")

#     players = []
#     table = soup.find("table", class_="items")
#     if not table:
#         return players  # No data

#     rows = table.find_all("tr", class_=["odd", "even"])
#     for row in rows:
#         name_tag = row.find("a", class_="spielprofil_tooltip")
#         if name_tag:
#             name = name_tag.text.strip()
#             profile_url = "https://www.transfermarkt.com" + name_tag['href']
#             players.append({
#                 "name": name,
#                 "profile_url": profile_url
#             })
#     return players

# # Example: Scrape first 5 pages
# all_players = []
# for page in range(1, 6):  # increase the range for more data
#     players = get_players_from_page(page)
#     if not players:
#         break
#     all_players.extend(players)
#     time.sleep(2)  # be respectful to Transfermarkt's servers

# print(f"Total players scraped: {len(all_players)}")
# for p in all_players[:10]:  # preview first 10
#     print(p)
# Out:
# Scraping: https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/page/1
# Total players scraped: 0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
(KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}

number=[]
name=[]
position=[]
age=[]
nation=[]
team=[]
value=[]

# %%
for i in range(1, 20):

    url = f"https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/plus/ajax/yw1/0//page/{i}"

    r= requests.get(url, headers=headers)
    r.status_code

    soup = BeautifulSoup(r.text, 'html.parser')

    player_info= soup.find_all('tr', class_=['odd', 'even'])
    # print(player_info)
    for info in player_info:
        player = info.find_all("td")

        number.append(player[0].text)
        name.append(player[3].text)
        position.append(player[4].text)
        age.append(player[5].text)
        nation.append(player[6].img['alt'])
        team.append(player[7].img['alt'])
        value.append(player[8].text.strip())
    time.sleep(1)

# %%
MarketVal_Table = pd.DataFrame(
        {"number":number,
         "name":name,
         "position":position,
         "age":age,
         "nation":nation,
         "team":team,
         "value":value}
    )
# MarketVal_Table.sort_values(by = 'name')
# Out:
#     number                name            position age      nation  \
# 430    431   Aaron Wan-Bissaka          Right-Back  27    DR Congo
# 197    198  Abdukodir Khusanov         Centre-Back  21  Uzbekistan
# 32      33       Achraf Hakimi          Right-Back  26     Morocco
# 124    125        Adam Wharton  Defensive Midfield  21     England
# 69      70     Ademola Lookman      Second Striker  27     Nigeria
# ..     ...                 ...                 ...  ..         ...
# 275    276         Zeno Debast         Centre-Back  21     Belgium
# 81      82          Álex Baena         Left Winger  24       Spain
# 195    196     Álvaro Carreras           Left-Back  22       Spain
# 296    297        Éder Militão         Centre-Back  27      Brazil
# 96      97             Éderson    Central Midfield  26      Brazil
#
#                     team    value
# 430      West Ham United  €24.00m
# 197      Manchester City  €35.00m
# 32   Paris Saint-Germain  €80.00m
# ...

# %%
MarketVal_Table.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/MarketVal.xlsx")

# %%
MarketVal_df = pd.read_excel("/content/drive/MyDrive/DissertationRetake/Dataset/MarketVal.xlsx")

# %%
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='value', y='age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from numpy.random import seed
from numpy.random import randint
from numpy.random import randn
import seaborn as sns
import statistics

# %%
import string
from scipy.stats import pearsonr
from scipy.stats import spearmanr
import sklearn
# import matplotlib.pyplot as plt
# from matplotlib import style
# import seaborn as sns

# %%
# source= requests.get('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats').text
# soup=BeautifulSoup(source,'lxml')
# table=soup.find_all('table')
PlayerStats = pd.read_html('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats', attrs={"id":"stats_standard"})[0]
# table = pd.read_html('https://fbref.com/en/comps/Big5/2019-2020/possession/squads/2019-2020-Big-5-European-Leagues-Stats', attrs={"id":"stats_teams_possession_for"})[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1013017052.py in <cell line: 0>()
#       2 # soup=BeautifulSoup(source,'lxml')
#       3 # table=soup.find_all('table')
# ----> 4 PlayerStats = pd.read_html('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats', attrs={"id":"stats_standard"})#[0]
#       5 # table = pd.read_html('https://fbref.com/en/comps/Big5/2019-2020/possession/squads/2019-2020-Big-5-European-Leagues-Stats', attrs={"id":"stats_teams_possession_for"})[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
#    1241         flavor=flavor,
# ...

# %%
# df = table
# df = pd.read_html(str(ta))
# df = df[0]
PlayerStats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-151914115.py in <cell line: 0>()
#       2 # df = pd.read_html(str(ta))
#       3 # df = df[0]
# ----> 4 PlayerStats
#
# NameError: name 'PlayerStats' is not defined

# %%
PlayerStats.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Football.xlsx")

# %%
df=pd.read_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Football.xlsx")

# %%
col=[]
for i in df.iloc[0]:
    col.append(i)

# %%
df.columns=col
df.drop(df.index[0],inplace=True)
df.iloc[0].drop
# df.drop([0], axis = 1,inplace=True)

df
# Out:
#          NaN    Rk            Player   Nation    Pos        Squad  \
# 1        NaN   NaN               NaN      NaN    NaN          NaN
# 2        0.0     1        Max Aarons  eng ENG     DF  Bournemouth
# 3        1.0     2        Max Aarons  eng ENG  DF,MF     Valencia
# 4        2.0     3    Rodrigo Abajas   es ESP     DF     Valencia
# 5        3.0     4    James Abankwah   ie IRL  DF,MF      Udinese
# ...      ...   ...               ...      ...    ...          ...
# 2965  2963.0    Rk            Player   Nation    Pos        Squad
# 2966  2964.0  2851  Szymon Żurkowski   pl POL     MF       Empoli
# 2967  2965.0  2852   Martin Ødegaard   no NOR     MF      Arsenal
# 2968  2966.0  2853       Milan Đurić   ba BIH     FW        Monza
# 2969  2967.0  2854       Milan Đurić   ba BIH     FW        Parma
#
#                     Comp  Age  Born   MP  ...   Ast   G+A  G-PK  G+A-PK    xG  \
# 1                    NaN  NaN   NaN  NaN  ...   NaN   NaN   NaN     NaN   NaN
# ...

# %%
col=[]
for i in df.columns:
    col.append(i)

# %%
col[0]='A'
df.columns=col
# df.drop(df['A'])
df.drop('A', axis = 1,inplace=True)
df.index=df['Rk']
df
# Out:
#         Rk            Player   Nation    Pos        Squad                Comp  \
# Rk
# NaN    NaN               NaN      NaN    NaN          NaN                 NaN
# 1        1        Max Aarons  eng ENG     DF  Bournemouth  eng Premier League
# 2        2        Max Aarons  eng ENG  DF,MF     Valencia          es La Liga
# 3        3    Rodrigo Abajas   es ESP     DF     Valencia          es La Liga
# 4        4    James Abankwah   ie IRL  DF,MF      Udinese          it Serie A
# ...    ...               ...      ...    ...          ...                 ...
# Rk      Rk            Player   Nation    Pos        Squad                Comp
# 2851  2851  Szymon Żurkowski   pl POL     MF       Empoli          it Serie A
# 2852  2852   Martin Ødegaard   no NOR     MF      Arsenal  eng Premier League
# 2853  2853       Milan Đurić   ba BIH     FW        Monza          it Serie A
# 2854  2854       Milan Đurić   ba BIH     FW        Parma          it Serie A
#
# ...

# %%
df.drop('Rk', axis = 1,inplace=True)
df
# Out:
#                 Player   Nation    Pos        Squad                Comp  Age  \
# Rk
# NaN                NaN      NaN    NaN          NaN                 NaN  NaN
# 1           Max Aarons  eng ENG     DF  Bournemouth  eng Premier League   24
# 2           Max Aarons  eng ENG  DF,MF     Valencia          es La Liga   24
# 3       Rodrigo Abajas   es ESP     DF     Valencia          es La Liga   21
# 4       James Abankwah   ie IRL  DF,MF      Udinese          it Serie A   20
# ...                ...      ...    ...          ...                 ...  ...
# Rk              Player   Nation    Pos        Squad                Comp  Age
# 2851  Szymon Żurkowski   pl POL     MF       Empoli          it Serie A   26
# 2852   Martin Ødegaard   no NOR     MF      Arsenal  eng Premier League   25
# 2853       Milan Đurić   ba BIH     FW        Monza          it Serie A   34
# 2854       Milan Đurić   ba BIH     FW        Parma          it Serie A   34
#
# ...

# %%
# df.drop('Rk', axis = 1,inplace=True)

# %%
df['Nation'] = df['Nation'].str.split(r' ').str.get(1)

# %%
df
# Out:
#                 Player Nation    Pos        Squad                Comp  Age  \
# Rk
# NaN                NaN    NaN    NaN          NaN                 NaN  NaN
# 1           Max Aarons    ENG     DF  Bournemouth  eng Premier League   24
# 2           Max Aarons    ENG  DF,MF     Valencia          es La Liga   24
# 3       Rodrigo Abajas    ESP     DF     Valencia          es La Liga   21
# 4       James Abankwah    IRL  DF,MF      Udinese          it Serie A   20
# ...                ...    ...    ...          ...                 ...  ...
# Rk              Player    NaN    Pos        Squad                Comp  Age
# 2851  Szymon Żurkowski    POL     MF       Empoli          it Serie A   26
# 2852   Martin Ødegaard    NOR     MF      Arsenal  eng Premier League   25
# 2853       Milan Đurić    BIH     FW        Monza          it Serie A   34
# 2854       Milan Đurić    BIH     FW        Parma          it Serie A   34
#
# ...

# %%
df['Comp'].unique()
# Out:
# array([nan, 'eng Premier League', 'es La Liga', 'it Serie A',
#        'fr Ligue 1', 'Comp', 'de Bundesliga'], dtype=object)

# %%
Eng_Premier = df[df['Comp'] == 'eng Premier League']
# Eng_Premier.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Eng_Premier.xlsx")
# La_Liga = df[df['Comp'] == 'es La Liga']
# La_Liga.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/La_Liga.xlsx")
# Serie_A = df[df['Comp'] == 'it Serie A']
# Serie_A.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Serie_A.xlsx")
# Ligue_1 = df[df['Comp'] == 'fr Ligue 1']
# Ligue_1.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Ligue_1.xlsx")
# Bundesliga = df[df['Comp'] == 'de Bundesliga']
# Bundesliga.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Bundesliga.xlsx")
# Eng_Premier.sort_values(by = 'Player')

# %%
# df['Comp'] = df['Comp'].str.split(r' ').str.get(1)
df = Eng_Premier

# %%
col=[]
for i in Eng_Premier.columns:
    col.append(i)

# %%
col[-2]='Ast90'
Eng_Premier.columns=col

# %%
Eng_Premier.dropna(inplace=True)
Eng_Premier.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR',
#        'Gls', 'Ast', 'G+A', 'G-PK', 'G+A-PK', 'xG', 'xAG', 'xG+xAG', 'npxG',
#        'Ast90', 'Matches'],
#       dtype='object')

# %%
# df['Gls+Ast']=df['Gls']+df['Ast']
# test = df['Player']
Eng_Premier.sort_values(by = ['Player'])
# Out:
#                          Player   Nation    Pos            Squad  \
# Rk
# 627             Aaron Cresswell  eng ENG     DF         West Ham
# 2173             Aaron Ramsdale  eng ENG     GK      Southampton
# 2744          Aaron Wan-Bissaka  eng ENG     DF         West Ham
# 773          Abdoulaye Doucouré   ml MLI     MF          Everton
# 1352         Abdukodir Khusanov   uz UZB     DF  Manchester City
# 877       Abdul Fatawu Issahaku   gh GHA     FW   Leicester City
# 153              Adam Armstrong  eng ENG  FW,MF      Southampton
# 1443               Adam Lallana  eng ENG     MF      Southampton
# 2455                 Adam Smith  eng ENG     DF      Bournemouth
# 2753               Adam Webster  eng ENG     DF         Brighton
# 2763               Adam Wharton  eng ENG     MF   Crystal Palace
# 2624               Adama Traoré   es ESP  FW,MF           Fulham
# 1072            Albert Grønbaek   dk DEN  FW,MF      Southampton
# ...

# %%
MarketVal_df.rename(columns={'name':'Player'},inplace=True)
MarketVal_df.sort_values(by = 'Player')
# MarketVal_df
# Out:
#      Unnamed: 0  number                    Player            position  age  \
# 430         430     431         Aaron Wan-Bissaka          Right-Back   27
# 197         197     198        Abdukodir Khusanov         Centre-Back   21
# 32           32      33             Achraf Hakimi          Right-Back   26
# 124         124     125              Adam Wharton  Defensive Midfield   21
# 69           69      70           Ademola Lookman      Second Striker   27
# 422         422     423             Adrien Rabiot    Central Midfield   30
# 460         460     461             Aitor Paredes         Centre-Back   25
# 235         235     236               Alan Varela  Defensive Midfield   24
# 355         355     356           Alberto Moleiro         Left Winger   21
# 64           64      65           Alejandro Balde           Left-Back   21
# 122         122     123        Alejandro Garnacho         Left Winger   21
# ...

# %%
pd.set_option('display.max_rows',600)
Stats_MarketValue = pd.merge(MarketVal_df, Eng_Premier, how="right", on=["Player"])

Stats_MarketValue.sort_values(by = 'Player')
# Out:
#      Unnamed: 0  number                     Player            position   age  \
# 111         NaN     NaN            Aaron Cresswell                 NaN   NaN
# 421         NaN     NaN             Aaron Ramsdale                 NaN   NaN
# 538       430.0   431.0          Aaron Wan-Bissaka          Right-Back  27.0
# 145         NaN     NaN         Abdoulaye Doucouré                 NaN   NaN
# 281       197.0   198.0         Abdukodir Khusanov         Centre-Back  21.0
# 174         NaN     NaN      Abdul Fatawu Issahaku                 NaN   NaN
# 32          NaN     NaN             Adam Armstrong                 NaN   NaN
# 296         NaN     NaN               Adam Lallana                 NaN   NaN
# 474         NaN     NaN                 Adam Smith                 NaN   NaN
# 544         NaN     NaN               Adam Webster                 NaN   NaN
# 548       124.0   125.0               Adam Wharton  Defensive Midfield  21.0
# ...

# %%
# Football1 = df
# df.to_excel("/content/drive/MyDrive/DissertationRetake/Dataset/Football1.xlsx")

# %%
df
# Out:
#                    Player Nation    Pos           Squad                Comp  \
# Rk
# 1              Max Aarons    ENG     DF     Bournemouth  eng Premier League
# 22      Joshua Acheampong    ENG     DF         Chelsea  eng Premier League
# 26            Tyler Adams    USA     MF     Bournemouth  eng Premier League
# 28       Tosin Adarabioyo    ENG     DF         Chelsea  eng Premier League
# 31          Simon Adingra    CIV  FW,MF        Brighton  eng Premier League
# ...                   ...    ...    ...             ...                 ...
# 2802         Ashley Young    ENG     DF         Everton  eng Premier League
# 2804       Illia Zabarnyi    UKR     DF     Bournemouth  eng Premier League
# 2840  Oleksandr Zinchenko    UKR  DF,MF         Arsenal  eng Premier League
# 2842       Joshua Zirkzee    NED  FW,MF  Manchester Utd  eng Premier League
# 2852      Martin Ødegaard    NOR     MF         Arsenal  eng Premier League
#
# ...

# %%
df=df.apply(pd.to_numeric, errors='ignore')
# Out:
# /tmp/ipython-input-1582836795.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df=df.apply(pd.to_numeric, errors='ignore')

# %%
df.rename(columns={'Market Value in Million € ':'MV'},inplace=True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1296245680.py in <cell line: 0>()
# ----> 1 df.rename(columns={'Market Value in Million € ':'MV'},inplace=True)
#       2 df.columns
#
# NameError: name 'df' is not defined

# %%
df.rename(columns={'Squad':'Club','Comp':'Leauge'},inplace=True)
df.rename(columns={'Club_x':'Club'},inplace=True)
df['CR']=0

for i in range(0,len(df)):
    if(df['Club'][i]=='PSG' or df['Club'][i]=='Manchester Utd' or df['Club'][i]=='Liverpool' or df['Club'][i]=='Real Madrid' or df['Club'][i]=='Barcelona' or df['Club'][i]=='Bayern Munich' or df['Club'][i]=='Juventus' or df['Club'][i]=='Atlético Madrid' or df['Club'][i]=='Inter' or df['Club'][i]=='Chelsea' or df['Club'][i]=='Manchester City' ):
        df['CR'][i]=1
    elif(df['Club'][i]=='Arsenal' or df['Club'][i]=='Tottenham' or df['Club'][i]=='Napoli' or df['Club'][i]=='Dortmund' or df['Club'][i]=='Leicester City' or df['Club'][i]=='Lyon' or df['Club'][i]=='Everton' or df['Club'][i]=='Valencia' or df['Club'][i]=='Sevilla' ):
        df['CR'][i]=2
    else:
        df['CR'][i]=3
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CR'][i]=3
# /tmp/ipython-input-517768031.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df['CR'][i]=3
# /tmp/ipython-input-517768031.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
df['MV']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'MV'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-479092916.py in <cell line: 0>()
# ----> 1 df['MV']
#
# ...

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.tight_layout()
sns.set_context('talk')
ax=sns.boxplot(y='Market Value in Million € ', x='CR',data=df,palette="colorblind")
ax.set(xlabel='Club Ranking', ylabel='Market Value in Million €',title='MV vs Club')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3035846769.py in <cell line: 0>()
#       2 plt.tight_layout()
#       3 sns.set_context('talk')
# ----> 4 ax=sns.boxplot(y='Market Value in Million € ', x='CR',data=df,palette="colorblind")
#       5 ax.set(xlabel='Club Ranking', ylabel='Market Value in Million €',title='MV vs Club')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1595 ):
#    1596
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#
# ...
